# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaushal000/Streamlit-coronavirus-detection-app/blob/main/Coronavirus_detection_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Get the runtime details**

# %%
# %cat /etc/lsb-release

# %% [markdown]
# **Update the Repo list**

# %%
# !apt-get update

# %% [markdown]
# **Show the current working directory**

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/sample_data
# Out:
# /content/sample_data

# %% [markdown]
# **Unzip the darknet zip file to the /content/darknet folder**

# %%
# !unzip darknet.zip
# Out:
# Archive:  darknet.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of darknet.zip or
#         darknet.zip.zip, and cannot find darknet.zip.ZIP, period.

# %% [markdown]
# **Copy the conents of drive to darknet folder**

# %%
# !cp -r /content/drive/MyDrive/darknet /content/darknet/

# %%
# %cd /content/darknet/darknet/darknet
# Out:
# /content/darknet/darknet/darknet

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir model

# %% [markdown]
# **Copy the model**

# %%
# !cp -r /content/drive/MyDrive/darknet /content/model

# %% [markdown]
# **Install dos2unix to convert dos files to unix encoding**

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (441 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
# %cd /content/model/darknet/darknet/
# Out:
# /content/model/darknet/darknet

# %%
# %pwd
# Out:
# '/content/model/darknet/darknet'

# %% [markdown]
# **Convert all files in darknet folder to unix encoding**

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# dos2unix: converting file ./src/tree.c to Unix format...
# dos2unix: converting file ./src/crnn_layer.h to Unix format...
# dos2unix: converting file ./src/yolo_layer.c to Unix format...
# dos2unix: converting file ./src/dropout_layer.c to Unix format...
# dos2unix: converting file ./src/crop_layer.h to Unix format...
# dos2unix: converting file ./src/matrix.h to Unix format...
# dos2unix: converting file ./src/avgpool_layer.h to Unix format...
# dos2unix: converting file ./src/local_layer.h to Unix format...
# dos2unix: converting file ./src/im2col.h to Unix format...
# dos2unix: converting file ./src/go.c to Unix format...
# dos2unix: converting file ./src/activations.h to Unix format...
# dos2unix: converting file ./src/demo.c to Unix format...
# dos2unix: converting file ./src/cpu_gemm.c to Unix format...
# dos2unix: converting file ./src/gaussian_yolo_layer.c to Unix format...
# dos2unix: converting file ./src/convolutional_layer.h to Unix format...
# ...

# %% [markdown]
# **Give executable permission for files in /content/darknet/darknet**

# %%
# !chmod +x /content/model/darknet/darknet

# %% [markdown]
# **Compile the darknet framework**

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %% [markdown]
# **Test the darkent framework with sample object detection**

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/dog.jpg -map -dont_show
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %% [markdown]
# **Remove the default backup folder of darknet in runtime**

# %%
rm -r /content/model/darknet/darknet/backup

# %% [markdown]
# **Create a symbolic link from runtime darknet folder to google drive backup folder with the name 'backup'**

# %%
# !ln -s /content/drive/MyDrive/cov_weights/backup /content/model/darknet/darknet/

# %% [markdown]
# **check the directory**

# %%
# %pwd
# Out:
# '/content/model/darknet/darknet'

# %% [markdown]
# **Proceed with fresh Training Using the cov dataset**

# %%
# !./darknet detector train cov_data/cov.data cov_yolov4.cfg /content/drive/MyDrive/cov_weights/backup/cov_yolov4_last.weights -map -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.747161, GIOU: 0.730363), Class: 0.994304, Obj: 0.580082, No Obj: 0.028824, .5R: 0.916667, .75R: 0.500000, count: 12, class_loss = 5.436531, iou_loss = 3.216232, total_loss = 8.652762
#  total_bbox = 497290, rewritten_bbox = 0.001207 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.815888, GIOU: 0.808243), Class: 0.996384, Obj: 0.501586, No Obj: 0.001390, .5R: 1.000000, .75R: 0.666667, count: 6, class_loss = 3.400949, iou_loss = 22.033957, total_loss = 25.434906
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.832839, GIOU: 0.827213), Class: 0.996460, Obj: 0.789487, No Obj: 0.015361, .5R: 1.000000, .75R: 0.850000, count: 20, class_loss = 2.564047, iou_loss = 20.218954, total_loss = 22.783001
# ...
